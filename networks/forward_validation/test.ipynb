# %%
import sys
sys.path.insert(0, '..')

import forward_validation as FV
import pandas as pd 
from importlib import reload
import MLPModel, LinearModel, Model_Training, DataDownload
import numpy as np

reload(MLPModel)
reload(LinearModel)
reload(Model_Training)
reload(FV)

import torch

# %%
ticker = "AAPL"
start = '2019-01-01'    # start date
end  = '2026-07-01'     # end date
interval = '1d'         # interval
train_ratio = 0.75
no_epoches = 100_000
lr = 0.0001
tx_fees_bpts = 10
threshold = 0.001
weight_decay = 5e-3

max_lags = 32

initial_train_size = 800
test_size = 100 

# Get the dataframe 
data = DataDownload.download_one_data(symbol=ticker, start = start, end = end, interval=interval)

feature_input = data["close_log_return"]

results = FV.walk_forward(
    returns=feature_input, model_factory=MLPModel.MLP,lookback = max_lags, 
    initial_train_size=initial_train_size, test_size=test_size
)
# results


fold_metrics = []

for fold_number, fold in results.groupby("fold"):
    metrics = FV.data_analysis(
        fold,
        transaction_fees_bpts=10,
    )

    metrics["fold"] = fold_number
    fold_metrics.append(metrics)

fold_metrics = pd.concat(
    fold_metrics,
    ignore_index=True,
).set_index("fold")

print(fold_metrics)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Relative Tolance Reached at Epoch 1628
# Fold 0: train = 800 test=100
# Relative Tolance Reached at Epoch 1300
# Fold 1: train = 900 test=100
# Relative Tolance Reached at Epoch 1979
# Fold 2: train = 1000 test=100
# Relative Tolance Reached at Epoch 1583
# Fold 3: train = 1100 test=100
# Relative Tolance Reached at Epoch 1929
# Fold 4: train = 1200 test=100
# Relative Tolance Reached at Epoch 1569
# Fold 5: train = 1300 test=100
# Relative Tolance Reached at Epoch 2315
# Fold 6: train = 1400 test=100
# Relative Tolance Reached at Epoch 2351
# Fold 7: train = 1500 test=100
# Relative Tolance Reached at Epoch 2114
# Fold 8: train = 1600 test=100
# Relative Tolance Reached at Epoch 3034
# Fold 9: train = 1700 test=100
#       Observations  pearson_ic  spearman_ic  zero_mse  model_mse  mse_ratio  \
# fold
# 0              100   -0.026803    -0.027604  0.000556   0.000806   1.450606
# 1              100   -0.003076    -0.014244  0.000533   0.000756   1.417599
# 2              100    0.174465     0.111645  0.000154   0.000250   1.621922
# 3              100   -0.037212     0.031293  0.000160   0.000349   2.184490
# 4              100   -0.011614    -0.039592  0.000157   0.000302   1.921515
# 5              100    0.017248     0.062506  0.000260   0.000375   1.442744
# 6              100    0.076311     0.050854  0.000199   0.000295   1.478489
# 7              100    0.001387     0.014451  0.000706   0.001503   2.128483
# 8              100   -0.050926    -0.098083  0.000212   0.000321   1.510971
# 9              100   -0.115365    -0.047583  0.000196   0.000342   1.744410
#
#       direction_accuracy  active_win_rate  active_fraction  total_turnver  \
# fold
# 0                   0.43             0.43              1.0           75.0
# 1                   0.51             0.50              1.0           57.0
# 2                   0.53             0.52              1.0           53.0
# 3                   0.47             0.44              1.0          105.0
# 4                   0.45             0.42              1.0           87.0
# 5                   0.60             0.59              1.0           45.0
# 6                   0.47             0.43              1.0           99.0
# 7                   0.49             0.48              1.0           75.0
# 8                   0.46             0.41              1.0           87.0
# 9                   0.46             0.42              1.0           97.0
#
#       net_return  annualized_sharpe  max_drawdown
# fold
# 0      -0.255958          -1.984492     -0.256041
# 1      -0.075699          -0.538814     -0.277793
# 2       0.207171           2.412852     -0.060722
# 3      -0.027170          -0.342020     -0.126597
# 4      -0.178063          -2.468957     -0.237918
# 5       0.077668           0.728400     -0.125456
# 6      -0.154256          -1.897449     -0.170755
# 7      -0.249220          -1.705694     -0.357627
# 8      -0.076650          -0.867166     -0.181845
# 9      -0.103617          -1.226379     -0.121901

# %%
ticker = "AAPL"
start = '2019-01-01'    # start date
end  = '2026-07-01'     # end date
interval = '1d'         # interval
train_ratio = 0.75
no_epoches = 100_000
lr = 0.0001
tx_fees_bpts = 10
threshold = 0.001
weight_decay = 5e-3

max_lags = 32

initial_train_size = 800
test_size = 100 

# Get the dataframe 
data = DataDownload.download_one_data(symbol=ticker, start = start, end = end, interval=interval)

feature_input = data["close_log_return"]

results = FV.walk_forward(
    returns=feature_input, model_factory=LinearModel.LinearModel,lookback = max_lags, 
    initial_train_size=initial_train_size, test_size=test_size
)
# results


fold_metrics = []

for fold_number, fold in results.groupby("fold"):
    metrics = FV.data_analysis(
        fold,
        transaction_fees_bpts=10,
    )

    metrics["fold"] = fold_number
    fold_metrics.append(metrics)

fold_metrics = pd.concat(
    fold_metrics,
    ignore_index=True,
).set_index("fold")

fold_metrics
# Out:
# [*********************100%***********************]  1 of 1 completed
# Relative Tolance Reached at Epoch 608
# Fold 0: train = 800 test=100
# Relative Tolance Reached at Epoch 593
# Fold 1: train = 900 test=100
# Relative Tolance Reached at Epoch 704
# Fold 2: train = 1000 test=100
# Relative Tolance Reached at Epoch 482
# Fold 3: train = 1100 test=100
# Relative Tolance Reached at Epoch 469
# Fold 4: train = 1200 test=100
# Relative Tolance Reached at Epoch 426
# Fold 5: train = 1300 test=100
# Relative Tolance Reached at Epoch 517
# Fold 6: train = 1400 test=100
# Relative Tolance Reached at Epoch 680
# Fold 7: train = 1500 test=100
# Relative Tolance Reached at Epoch 455
# Fold 8: train = 1600 test=100
# Relative Tolance Reached at Epoch 400
# Fold 9: train = 1700 test=100
#       Observations  pearson_ic  spearman_ic  zero_mse  model_mse  mse_ratio  \
# fold
# 0              100    0.127999     0.151839  0.000556   0.000564   1.015655
# 1              100    0.041578    -0.038824  0.000533   0.000560   1.050830
# 2              100   -0.000689     0.024062  0.000154   0.000162   1.050095
# 3              100   -0.136897    -0.086805  0.000160   0.000183   1.147077
# 4              100   -0.064365    -0.082652  0.000157   0.000175   1.114871
# 5              100   -0.168841    -0.163852  0.000260   0.000286   1.098510
# 6              100    0.038891     0.084656  0.000199   0.000204   1.022413
# 7              100   -0.048931    -0.208077  0.000706   0.000761   1.078563
# 8              100   -0.217450    -0.190075  0.000212   0.000228   1.072050
# 9              100   -0.022241    -0.010513  0.000196   0.000204   1.037387
#
#       direction_accuracy  active_win_rate  active_fraction  total_turnver  \
# fold
# 0                   0.56             0.52              1.0          139.0
# 1                   0.46             0.45              1.0          125.0
# 2                   0.54             0.48              1.0          117.0
# 3                   0.49             0.48              1.0           87.0
# 4                   0.41             0.38              1.0           93.0
# 5                   0.54             0.50              1.0          121.0
# 6                   0.52             0.52              1.0          103.0
# 7                   0.39             0.39              1.0          109.0
# 8                   0.47             0.46              1.0           87.0
# 9                   0.46             0.44              1.0           69.0
#
#       net_return  annualized_sharpe  max_drawdown
# fold
# 0       0.208451           1.281300     -0.156843
# 1      -0.028418          -0.196370     -0.221315
# 2      -0.054956          -0.711629     -0.144267
# 3      -0.182207          -2.548857     -0.218647
# 4      -0.199888          -2.795353     -0.227657
# 5      -0.081233          -0.822810     -0.171064
# 6      -0.001730          -0.019473     -0.115263
# 7      -0.356181          -2.633767     -0.375435
# 8      -0.298007          -3.883464     -0.283985
# 9      -0.178671          -2.202866     -0.257731
